# %%
spark.sql("DESCRIBE DETAIL data_catalogue.silver.sales")

# %%
detail = spark.sql("DESCRIBE DETAIL data_catalogue.silver.sales")
display(detail)

# %%
detail.select("format", "location").show(truncate=False)

# %%
display(
    dbutils.fs.ls(
        "abfss://project5@adlgen2testproject.dfs.core.windows.net/"
    )
)

# %%
df_sales = spark.table("data_catalogue.silver.sales")

display(df_sales)

# %%
delta_path = "abfss://project5@adlgen2testproject.dfs.core.windows.net/delta/sales_delta"

df_sales.write \
    .format("delta") \
    .mode("overwrite") \
    .save(delta_path)
