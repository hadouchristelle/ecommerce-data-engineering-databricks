# %%
dbutils.widgets.text(
    "source_path",
    "/Volumes/training_catalog/christelle_schema/raw_files/incremental_input/"
)

source_path = dbutils.widgets.get("source_path")

print("Source path:", source_path)

# %%
dbutils.fs.mkdirs(source_path)
